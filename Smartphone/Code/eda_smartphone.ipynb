# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('FeatureExtraction_smartPhone.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index     Brand                      model  price  rating  \
# 0           0      0   oneplus              OnePlus 11 5G  54999    89.0
# 1           1      1   oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0
# 2           2      2   samsung      Samsung Galaxy A14 5G  16499    75.0
# 3           3      3  motorola       Motorola Moto G62 5G  14999    81.0
# 4           4      4    realme         Realme 10 Pro Plus  24999    82.0
#
#      5G    NFC  IR Blaster Processor Brand  ... Fast Charging Available  \
# 0  True   True       False      snapdragon  ...                    True
# 1  True  False       False      snapdragon  ...                    True
# 2  True  False       False          exynos  ...                    True
# 3  True  False       False      snapdragon  ...                    True
# 4  True  False       False       dimensity  ...                    True
#
#    Fast Charging Capacity(Wat)  Display Size  Refresh Rate(in Hz)  \
# ...

# %% [markdown]
# # 📊 Univariate Analysis
#
# Univariate analysis focuses on analyzing *a single variable* at a time. It helps in understanding the *distribution, **central tendency, and **spread* of the data for one column.
#
# ---
#
# ## 🎯 Purpose
#
# - Understand the basic structure of the data
# - Detect outliers or unusual patterns
# - Identify data skewness
# - Assist in selecting appropriate transformation techniques
#
# ---

# %%
data['Brand'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%',colormap='plasma')
sns.set_theme(style='whitegrid')
plt.title("Market Capture By Smartphone Brands")
# Out:
# Text(0.5, 1.0, 'Market Capture By Smartphone Brands')

# %%
sns.histplot(data=data,x=data['price'])
plt.title("Price Graph")
# Out:
# Text(0.5, 1.0, 'Price Graph')

# %%
data['price'].describe().plot(kind='bar')
plt.xticks(rotation = 45)
plt.title("Price Summary statistics")
# Out:
# Text(0.5, 1.0, 'Price Summary statistics')

# %%
sns.histplot(data=data,x=data['rating'])
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
data['5G'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['NFC'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['IR Blaster'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['Processor Brand'].value_counts().head().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['Fast Charging Available'].value_counts().head().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['Fast Charging Capacity(Wat)'].value_counts(10).head().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='proportion'>

# %%
sns.histplot(data=data,x=data['Display Size'],bins=30)
# Out:
# <Axes: xlabel='Display Size', ylabel='Count'>

# %%
sns.kdeplot(data=data,x=data['Display Size'],fill=True)
# Out:
# <Axes: xlabel='Display Size', ylabel='Density'>

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Brand', 'model', 'price', 'rating', '5G', 'NFC',
#        'IR Blaster', 'Processor Brand', 'Processor Name', 'Processor Core',
#        'Processor Speed', 'Ram(in Gb)', 'Rom(in Gb)',
#        'Battery Capacity(in mAh)', 'Fast Charging Available',
#        'Fast Charging Capacity(Wat)', 'Display Size', 'Refresh Rate(in Hz)',
#        'Number of Camera', 'Primary Rear Camera', 'Primary Front Camera',
#        'Memory Card Support', 'Extended Memory Capacity(in Gb)', 'os'],
#       dtype='object')

# %%
sns.kdeplot(data=data,x=data['Refresh Rate(in Hz)'],fill=True)
# Out:
# <Axes: xlabel='Refresh Rate(in Hz)', ylabel='Density'>

# %%
data['Number of Camera'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data['os'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 📊 Bivariate Analysis - Smartphone Dataset
#
# In this section, we explore relationships between *two variables* to uncover trends, patterns, and potential dependencies. This helps us understand how one feature affects another — for example, how *price* varies by *brand* or how *display size* correlates with *battery capacity*.

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=data, x = data['price'], y = data['Brand'],estimator='mean')
# Out:
# <Axes: xlabel='price', ylabel='Brand'>

# %%
data[data['Brand'] == 'vertu']
# Out:
#      Unnamed: 0  index  Brand                  model   price  rating     5G  \
# 426         426    426  vertu  Vertu Signature Touch  650000    62.0  False
#
#       NFC  IR Blaster Processor Brand  ... Fast Charging Available  \
# 426  True       False      snapdragon  ...                   False
#
#      Fast Charging Capacity(Wat)  Display Size  Refresh Rate(in Hz)  \
# 426                          NaN           4.7                   60
#
#      Number of Camera  Primary Rear Camera  Primary Front Camera  \
# 426                 1                 13.0                   2.1
#
#      Memory Card Support  Extended Memory Capacity(in Gb)       os
# 426                False                              NaN  android
#
# [1 rows x 26 columns]

# %%
data.drop(426,inplace=True)
# Outlier

# %%
sns.boxenplot(data=data,  y= data['price'])
# Out:
# <Axes: ylabel='price'>

# %%
sns.barplot(data=data, x = data['price'], y = data['Processor Brand'])
# Out:
# <Axes: xlabel='price', ylabel='Processor Brand'>

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Brand', 'model', 'price', 'rating', '5G', 'NFC',
#        'IR Blaster', 'Processor Brand', 'Processor Name', 'Processor Core',
#        'Processor Speed', 'Ram(in Gb)', 'Rom(in Gb)',
#        'Battery Capacity(in mAh)', 'Fast Charging Available',
#        'Fast Charging Capacity(Wat)', 'Display Size', 'Refresh Rate(in Hz)',
#        'Number of Camera', 'Primary Rear Camera', 'Primary Front Camera',
#        'Memory Card Support', 'Extended Memory Capacity(in Gb)', 'os'],
#       dtype='object')

# %%
plt.scatter(x = data['price'], y = data['rating'])
# its Show that low budget Phone also have High Rating

# %%
plt.scatter(x = data['price'], y = data['Battery Capacity(in mAh)'])

# %%
plt.scatter(x = data['price'], y = data['Refresh Rate(in Hz)'])

# %%
sns.barplot(x = data['price'], y = data['os'])
# Out:
# <Axes: xlabel='price', ylabel='os'>

# %%
plt.scatter(data['price'],data['Number of Camera'])

# %%
sns.barplot(data = data, x = data['Ram(in Gb)'],y = data['price'])
# Out:
# <Axes: xlabel='Ram(in Gb)', ylabel='price'>
